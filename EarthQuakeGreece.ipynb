# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# 'D:\\Anaconda Files'

# %%
cd D:\Anaconda Files
# Out:
# D:\Anaconda Files

# %%
df = pd.read_csv('EarthQuakes in Greece.csv')

# %%
df
# Out:
#         Year  Month  Date  Hours  Minutes  LATATITUDE (N)  LONGITUDE  (E)  \
# 0       1901      9    12      6       15           39.00           22.20
# 1       1901     10    25     16       18           37.00           22.20
# 2       1901     12    24     23       18           37.20           22.20
# 3       1902      4    11     18       35           38.50           23.50
# 4       1902      7     5     14       56           40.80           23.20
# 5       1902      8     2      5       38           38.50           21.80
# 6       1902     11     5     23       50           38.20           20.50
# 7       1903      3    15     19        3           37.80           21.20
# 8       1903      3    25     22       30           36.00           25.00
# 9       1903      5    29      9       34           39.80           18.70
# 10      1903      7    21     13        3           38.20           21.80
# 11      1903      8    11      4       32           36.30           23.00
# 12      1903      9    19     18       51           37.80           20.80
# 13      1903     11    25     23       16           42.10           23.20
# 14      1904      4     4     10        2           41.78           22.98
# 15      1904      4     4     10       25           41.80           23.10
# 16      1904      4     4     10       30           42.10           23.40
# 17      1904      4     4     11        9           42.00           23.00
# 18      1904      4     5      9       33           37.80           22.20
# 19      1904      4    13      9       55           42.41           22.80
# 20      1904      4    19     18       14           42.00           23.10
# 21      1904      4    25     20        2           42.00           23.00
# 22      1904      5    19     10        2           38.40           27.20
# 23      1904      8    11      6        8           37.70           26.90
# 24      1904      8    18     20        7           38.00           27.00
# 25      1904     10    10     17       40           38.40           27.20
# 26      1905      1    20      2       32           39.70           22.90
# 27      1905      4    15      5       36           40.20           29.00
# 28      1905      6     1      4       42           42.00           19.50
# 29      1905      6     1     21       46           42.30           19.20
# ...      ...    ...   ...    ...      ...             ...             ...
# 256625  2018      5    28      6       14           39.26           20.58
# 256626  2018      5    28      7       43           38.65           22.79
# 256627  2018      5    28      8       28           36.06           23.54
# 256628  2018      5    28      8       39           38.36           21.26
# 256629  2018      5    28      8       54           38.37           21.27
# 256630  2018      5    28     13        4           36.57           22.88
# 256631  2018      5    28     13       53           37.54           21.66
# 256632  2018      5    28     18        6           38.15           23.83
# 256633  2018      5    28     18        9           35.54           23.28
# 256634  2018      5    28     19        4           38.08           23.92
# 256635  2018      5    28     19       54           38.96           23.14
# 256636  2018      5    28     20       41           38.70           22.80
# 256637  2018      5    28     21       28           38.82           23.03
# 256638  2018      5    28     22        6           38.89           23.49
# 256639  2018      5    28     22       24           38.41           21.98
# 256640  2018      5    28     23        3           38.22           21.70
# 256641  2018      5    28     23       11           34.62           24.06
# 256642  2018      5    28     23       32           38.40           21.96
# 256643  2018      5    28     23       51           39.23           20.95
# 256644  2018      5    29      0       20           39.24           20.93
# 256645  2018      5    29      4       33           38.37           21.87
# 256646  2018      5    29      6       10           34.75           24.92
# 256647  2018      5    29      6       11           37.46           21.82
# 256648  2018      5    29      7        0           37.95           22.02
# 256649  2018      5    29      7       44           38.36           21.84
# 256650  2018      5    29      9       29           38.57           20.96
# 256651  2018      5    29     10       25           39.57           25.99
# 256652  2018      5    29     10       51           39.59           25.97
# 256653  2018      5    29     10       58           39.99           20.59
# 256654  2018      5    29     12       55           39.58           25.99
#
#         MAGNITUDE (Richter)
# 0                       5.6
# 1                       5.4
# 2                       5.8
# 3                       5.8
# 4                       6.6
# 5                       5.6
# 6                       5.5
# 7                       5.7
# 8                       5.5
# 9                       6.0
# 10                      5.6
# 11                      8.0
# 12                      5.5
# 13                      6.5
# 14                      7.1
# 15                      7.8
# 16                      5.4
# 17                      5.5
# 18                      5.5
# 19                      5.5
# 20                      5.9
# 21                      5.5
# 22                      5.4
# 23                      6.2
# 24                      6.0
# 25                      5.8
# 26                      5.6
# 27                      5.6
# 28                      6.6
# 29                      5.5
# ...                     ...
# 256625                  1.8
# 256626                  2.2
# 256627                  2.2
# 256628                  1.4
# 256629                  1.4
# 256630                  2.0
# 256631                  2.4
# 256632                  1.5
# 256633                  3.1
# 256634                  1.6
# 256635                  1.4
# 256636                  3.2
# 256637                  1.6
# 256638                  1.6
# 256639                  2.5
# 256640                  1.7
# 256641                  3.0
# 256642                  1.2
# 256643                  1.1
# 256644                  2.4
# 256645                  1.6
# 256646                  2.5
# 256647                  3.3
# 256648                  2.3
# 256649                  2.1
# 256650                  1.7
# 256651                  3.9
# 256652                  3.6
# 256653                  2.5
# 256654                  2.2
#
# [256655 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256655 entries, 0 to 256654
# Data columns (total 8 columns):
# Year                   256655 non-null int64
# Month                  256655 non-null int64
# Date                   256655 non-null int64
# Hours                  256655 non-null int64
# Minutes                256655 non-null int64
# LATATITUDE (N)         256655 non-null float64
# LONGITUDE  (E)         256655 non-null float64
# MAGNITUDE (Richter)    256655 non-null float64
# dtypes: float64(3), int64(5)
# memory usage: 15.7 MB

# %%
df.dropna()
# Out:
#         Year  Month  Date  Hours  Minutes  LATATITUDE (N)  LONGITUDE  (E)  \
# 0       1901      9    12      6       15           39.00           22.20
# 1       1901     10    25     16       18           37.00           22.20
# 2       1901     12    24     23       18           37.20           22.20
# 3       1902      4    11     18       35           38.50           23.50
# 4       1902      7     5     14       56           40.80           23.20
# 5       1902      8     2      5       38           38.50           21.80
# 6       1902     11     5     23       50           38.20           20.50
# 7       1903      3    15     19        3           37.80           21.20
# 8       1903      3    25     22       30           36.00           25.00
# 9       1903      5    29      9       34           39.80           18.70
# 10      1903      7    21     13        3           38.20           21.80
# 11      1903      8    11      4       32           36.30           23.00
# 12      1903      9    19     18       51           37.80           20.80
# 13      1903     11    25     23       16           42.10           23.20
# 14      1904      4     4     10        2           41.78           22.98
# 15      1904      4     4     10       25           41.80           23.10
# 16      1904      4     4     10       30           42.10           23.40
# 17      1904      4     4     11        9           42.00           23.00
# 18      1904      4     5      9       33           37.80           22.20
# 19      1904      4    13      9       55           42.41           22.80
# 20      1904      4    19     18       14           42.00           23.10
# 21      1904      4    25     20        2           42.00           23.00
# 22      1904      5    19     10        2           38.40           27.20
# 23      1904      8    11      6        8           37.70           26.90
# 24      1904      8    18     20        7           38.00           27.00
# 25      1904     10    10     17       40           38.40           27.20
# 26      1905      1    20      2       32           39.70           22.90
# 27      1905      4    15      5       36           40.20           29.00
# 28      1905      6     1      4       42           42.00           19.50
# 29      1905      6     1     21       46           42.30           19.20
# ...      ...    ...   ...    ...      ...             ...             ...
# 256625  2018      5    28      6       14           39.26           20.58
# 256626  2018      5    28      7       43           38.65           22.79
# 256627  2018      5    28      8       28           36.06           23.54
# 256628  2018      5    28      8       39           38.36           21.26
# 256629  2018      5    28      8       54           38.37           21.27
# 256630  2018      5    28     13        4           36.57           22.88
# 256631  2018      5    28     13       53           37.54           21.66
# 256632  2018      5    28     18        6           38.15           23.83
# 256633  2018      5    28     18        9           35.54           23.28
# 256634  2018      5    28     19        4           38.08           23.92
# 256635  2018      5    28     19       54           38.96           23.14
# 256636  2018      5    28     20       41           38.70           22.80
# 256637  2018      5    28     21       28           38.82           23.03
# 256638  2018      5    28     22        6           38.89           23.49
# 256639  2018      5    28     22       24           38.41           21.98
# 256640  2018      5    28     23        3           38.22           21.70
# 256641  2018      5    28     23       11           34.62           24.06
# 256642  2018      5    28     23       32           38.40           21.96
# 256643  2018      5    28     23       51           39.23           20.95
# 256644  2018      5    29      0       20           39.24           20.93
# 256645  2018      5    29      4       33           38.37           21.87
# 256646  2018      5    29      6       10           34.75           24.92
# 256647  2018      5    29      6       11           37.46           21.82
# 256648  2018      5    29      7        0           37.95           22.02
# 256649  2018      5    29      7       44           38.36           21.84
# 256650  2018      5    29      9       29           38.57           20.96
# 256651  2018      5    29     10       25           39.57           25.99
# 256652  2018      5    29     10       51           39.59           25.97
# 256653  2018      5    29     10       58           39.99           20.59
# 256654  2018      5    29     12       55           39.58           25.99
#
#         MAGNITUDE (Richter)
# 0                       5.6
# 1                       5.4
# 2                       5.8
# 3                       5.8
# 4                       6.6
# 5                       5.6
# 6                       5.5
# 7                       5.7
# 8                       5.5
# 9                       6.0
# 10                      5.6
# 11                      8.0
# 12                      5.5
# 13                      6.5
# 14                      7.1
# 15                      7.8
# 16                      5.4
# 17                      5.5
# 18                      5.5
# 19                      5.5
# 20                      5.9
# 21                      5.5
# 22                      5.4
# 23                      6.2
# 24                      6.0
# 25                      5.8
# 26                      5.6
# 27                      5.6
# 28                      6.6
# 29                      5.5
# ...                     ...
# 256625                  1.8
# 256626                  2.2
# 256627                  2.2
# 256628                  1.4
# 256629                  1.4
# 256630                  2.0
# 256631                  2.4
# 256632                  1.5
# 256633                  3.1
# 256634                  1.6
# 256635                  1.4
# 256636                  3.2
# 256637                  1.6
# 256638                  1.6
# 256639                  2.5
# 256640                  1.7
# 256641                  3.0
# 256642                  1.2
# 256643                  1.1
# 256644                  2.4
# 256645                  1.6
# 256646                  2.5
# 256647                  3.3
# 256648                  2.3
# 256649                  2.1
# 256650                  1.7
# 256651                  3.9
# 256652                  3.6
# 256653                  2.5
# 256654                  2.2
#
# [256655 rows x 8 columns]

# %%
x_data= df.dropna().loc[: ,['Year']].values
sample= len(x_data)
x_ones= np.ones((sample, 1))
x_final= np.append(x_ones , x_data, axis =1)
y_final = df.dropna().loc[: ,['MAGNITUDE (Richter)']].values

# %%
new_beta=np.random.rand(2,1)

# %%
for i in range(8):
    y_pred= np.dot(x_final , new_beta)
    derivative = -2*(np.dot(np.transpose(y_final- y_pred),x_final))/sample
    new_beta = new_beta-(0.1*derivative.T)
    cost= ((y_final-y_pred)**2)/sample

# %%
y_pred= int(input('Enter the Year for which you want the prediction to occur? '))
y_cap= y_pred*new_beta[1]+ new_beta[0]
# Out:
# Enter the Year for which you want the prediction to occur? 2019

# %%
y_cap
# Out:
# array([2.79568385e+50])

# %%
a=df.groupby('Year')['MAGNITUDE (Richter)'].mean().plot(kind = 'bar',figsize= (25,10),color= 'purple',title='Magnitude of Earthquakes w.r.t Years')
